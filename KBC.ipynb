# %%
questions = [
  [
    "Which language was used to create fb?", "Python", "French", "JavaScript",
    "Php", "None", 4
 ],
  [
    "Which of the following planets is known as the 'Red Planet'?", "Earth"," Mars"," Jupiter",
    "Saturn","None",2
  ],
  [
    "Which Indian city is known as the 'Pink City'?", "Jaipur", "Mumbai", "Palghar",
    "Udaipur", "None", 1
  ],
  [
    " Which ancient Indian kingdom was founded by Chandragupta Maurya?", "Magadha", "Maurya", "Gupta",
    "Kushan", "None", 2
  ],

  [
    " Who wrote the famous novel 'To Kill a Mockingbird'?", " F. Scott Fitzgerald", "Harper Lee", "Jane Austen",
    "Kushan", "None", 2
  ],
  [
    " Who is the author of the famous Indian poem 'Gitanjali'?", " Rabindranath Tagore", " Subramania Bharati", "Vallathol Narayana Menon",
    "Sarojini Naidu", "None", 1
  ],

  [
    "Which company developed the operating system Android?", " GOOGLE", "Apple", "Microsoft",
    "Amazon", "None", 1
  ],
  [
    "Which technology enables wireless internet connectivity?", "Bluetooth", "Wi-Fi", " NFC",
    "RFID", "None", 2
  ],
  [
    "Which technology enables fingerprint recognition?", "Capacitive sensing", "Optical sensing", "Ultrasonic sensing",
    "Electromagnetic sensing", "None", 1
  ],
  [
    "Which type of encryption uses a public and private key pair?", "Symmetric key encryption", "Asymmetric key encryption", "Hash function",
    "Digital signature", "None", 2
  ],
]

# %%
levels = [1000, 2000, 3000, 5000, 10000, 20000, 40000, 80000, 160000, 320000]

# %%
money = 0
for i in range(0, len(questions)):

  question = questions[i]
  print(f"\n\nQuestion for Rs. {levels[i]}")
  print(f"a. {question[1]}          b. {question[2]} ")
  print(f"c. {question[3]}          d. {question[4]} ")
  reply = int(input("Enter your answer (1-4) or  0 to quit:\n" ))
  if (reply == 0):
    money = levels[i-1]
    break
  if(reply == question[-1]):
    print(f"Correct answer, you have won Rs. {levels[i]}")
    if(i == 4):
      money = 10000
    elif(i == 9):
      money = 320000
    elif(i == 14):
      money = 10000000
  else:
    print("Wrong answer!")
    break

print(f"Your take home money is {money}")
# Out:
# Question for Rs. 1000
# a. Python          b. French
# c. JavaScript          d. Php
# Enter your answer (1-4) or  0 to quit:
# 4
# Correct answer, you have won Rs. 1000
#
#
# Question for Rs. 2000
# a. Earth          b.  Mars
# c.  Jupiter          d. Saturn
# Enter your answer (1-4) or  0 to quit:
# 2
# Correct answer, you have won Rs. 2000
#
#
# Question for Rs. 3000
# a. Jaipur          b. Mumbai
# c. Palghar          d. Udaipur
# Enter your answer (1-4) or  0 to quit:
# 1
# Correct answer, you have won Rs. 3000
#
#
# Question for Rs. 5000
# a. Magadha          b. Maurya
# c. Gupta          d. Kushan
# Enter your answer (1-4) or  0 to quit:
# 2
# Correct answer, you have won Rs. 5000
#
#
# Question for Rs. 10000
# a.  F. Scott Fitzgerald          b. Harper Lee
# c. Jane Austen          d. Kushan
# Enter your answer (1-4) or  0 to quit:
# 2
# Correct answer, you have won Rs. 10000
#
#
# Question for Rs. 20000
# a.  Rabindranath Tagore          b.  Subramania Bharati
# ...
